# %%
import sys
sys.path.append('../')
from Secrets.openai_key import openapi_key
import os

# %%
os.environ['OPENAI_API_KEY'] = openapi_key

# %%
from langchain_openai import OpenAI
llm = OpenAI()
llm.invoke("I want to open a restaurant for Algerian food. suggest me a fancy name for this.")

# llm = OpenAI(model_kwargs={"temperature": 0.6})
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[3], line 3
#       1 from langchain_openai import OpenAI
#       2 llm = OpenAI()
# ----> 3 llm.invoke("I want to open a restaurant for Algerian food. suggest me a fancy name for this.")
#       5 # llm = OpenAI(model_kwargs={"temperature": 0.6})
#
# File ~/PycharmProjects/LangChainProject/venv/lib/python3.10/site-packages/langchain_core/language_models/llms.py:392, in BaseLLM.invoke(self, input, config, stop, **kwargs)
#     381 @override
#     382 def invoke(
#     383     self,
#    (...)
#     388     **kwargs: Any,
#     389 ) -> str:
#     390     config = ensure_config(config)
#     391     return (
# --> 392         self.generate_prompt(
#     393             [self._convert_input(input)],
#     394             stop=stop,
#     395             callbacks=config.get("callbacks"),
# ...

# %%
name = llm("I want to open a restaurant for Algerian food. suggest me a fancy name for this.")
print(name)
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 name = llm("I want to open a restaurant for Algerian food. suggest me a fancy name for this.")
#       2 print(name)
#
# File ~/PycharmProjects/LangChainProject/venv/lib/python3.10/site-packages/langchain_core/_api/deprecation.py:193, in deprecated.<locals>.deprecate.<locals>.warning_emitting_wrapper(*args, **kwargs)
#     191     warned = True
#     192     emit_warning()
# --> 193 return wrapped(*args, **kwargs)
#
# File ~/PycharmProjects/LangChainProject/venv/lib/python3.10/site-packages/langchain_core/language_models/llms.py:1349, in BaseLLM.__call__(self, prompt, stop, callbacks, tags, metadata, **kwargs)
#    1342     msg = (
#    1343         "Argument `prompt` is expected to be a string. Instead found "
#    1344         f"{type(prompt)}. If you want to run the LLM on multiple prompts, use "
# ...
